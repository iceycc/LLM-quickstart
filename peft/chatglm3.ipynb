# %%
# !pip install protobuf transformers==4.30.2 cpm_kernels gradio mdtex2html sentencepiece accelerate
# !pip install -U torch
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 83.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 100.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 32.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 43.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 88.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 83.5 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
from transformers import AutoTokenizer, AutoModel
import torch
device = torch.device("mps")
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm3-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm3-6b", trust_remote_code=True).to(device).half()
    #.cuda()
# Out:
# Loading checkpoint shards: 100%|██████████| 7/7 [00:05<00:00,  1.37it/s]

# %%
model = model.eval()
response, history = model.chat(tokenizer, "你好", history=[])
print(response)
response, history = model.chat(tokenizer, "怎么学好大模型呢？", history=history)
print(response)
# Out:
# 你好👋！我是人工智能助手 ChatGLM3-6B，很高兴见到你，欢迎问我任何问题。
# 学习大模型 (如 ChatGLM3-6B) 需要掌握以下几个步骤：
#
# 1. 掌握基础知识：学习计算机科学、数学和语言学等基础知识，这些知识对于理解大模型的原理和应用非常重要。
#
# 2. 熟悉大模型：了解大模型的结构、特点和应用场景，这样才能更好地利用大模型解决问题。
#
# 3. 学习大模型的训练：掌握大模型的训练方法和技术，如深度学习、强化学习、生成对抗网络等，了解大模型的训练过程和优化策略。
#
# 4. 实践应用：通过实践来提高自己的技能，可以尝试使用大模型解决一些实际问题，如自然语言处理、图像识别、推荐系统等。
#
# 5. 持续学习：大模型是一个快速发展的领域，需要不断学习新的技术和方法，跟上大模型的最新进展。
#
# 学习大模型需要投入大量的时间和精力，需要有强烈的兴趣和毅力。同时，还需要具备一定的编程和算法能力，能够进行模型的开发和优化。
